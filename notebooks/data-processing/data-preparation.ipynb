# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install python-dotenv requests
# Out:
# Requirement already satisfied: python-dotenv in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: requests in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikol\desktop\movie-recommendation-system\.venv\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import os
import requests
from dotenv import load_dotenv
import time
import re

# %%
df_users = pd.read_csv("../../datasets/users.dat", 
                         delimiter="::",
                         engine="python", 
                         encoding="ISO-8859-1", 
                         header=None,
                         names=['Id', 'Gender', 'Age', 'Occupation', 'Zip-code'], 
                         index_col=0)
df_users
# Out:
#      Gender  Age  Occupation Zip-code
# Id
# 1         F    1          10    48067
# 2         M   56          16    70072
# 3         M   25          15    55117
# 4         M   45           7    02460
# 5         M   25          20    55455
# ...     ...  ...         ...      ...
# 6036      F   25          15    32603
# 6037      F   45           1    76006
# 6038      F   56           1    14706
# 6039      F   45           0    01060
# 6040      M   25           6    11106
#
# [6040 rows x 4 columns]

# %%
df_ratings = pd.read_csv("../../datasets/ratings.dat", 
                         delimiter="::",
                         engine="python", 
                         encoding="ISO-8859-1", 
                         header=None,
                         names=['UserID', 'MovieID', 'Rating', 'Timestamp'], 
                         index_col=[0, 1])
df_ratings
# Out:
#                 Rating  Timestamp
# UserID MovieID
# 1      1193          5  978300760
#        661           3  978302109
#        914           3  978301968
#        3408          4  978300275
#        2355          5  978824291
# ...                ...        ...
# 6040   1091          1  956716541
#        1094          5  956704887
#        562           5  956704746
#        1096          4  956715648
#        1097          4  956715569
#
# [1000209 rows x 2 columns]

# %%
df_movies = pd.read_csv("../../datasets/movies.dat", 
                         delimiter="::",
                         engine="python", 
                         encoding="ISO-8859-1", 
                         header=None,
                         names=['Id', 'Name', 'Genres'], 
                         index_col=0)
df_movies
# Out:
#                                     Name                        Genres
# Id
# 1                       Toy Story (1995)   Animation|Children's|Comedy
# 2                         Jumanji (1995)  Adventure|Children's|Fantasy
# 3                Grumpier Old Men (1995)                Comedy|Romance
# 4               Waiting to Exhale (1995)                  Comedy|Drama
# 5     Father of the Bride Part II (1995)                        Comedy
# ...                                  ...                           ...
# 3948             Meet the Parents (2000)                        Comedy
# 3949          Requiem for a Dream (2000)                         Drama
# 3950                    Tigerland (2000)                         Drama
# 3951             Two Family House (2000)                         Drama
# 3952               Contender, The (2000)                Drama|Thriller
#
# [3883 rows x 2 columns]

# %%
df_genres = df_movies['Genres'].str.get_dummies(sep='|')

# %%
df_movies = pd.concat([df_movies[['Name']], df_genres], axis=1)
df_movies
# Out:
#                                     Name  Action  Adventure  Animation  \
# Id
# 1                       Toy Story (1995)       0          0          1
# 2                         Jumanji (1995)       0          1          0
# 3                Grumpier Old Men (1995)       0          0          0
# 4               Waiting to Exhale (1995)       0          0          0
# 5     Father of the Bride Part II (1995)       0          0          0
# ...                                  ...     ...        ...        ...
# 3948             Meet the Parents (2000)       0          0          0
# 3949          Requiem for a Dream (2000)       0          0          0
# 3950                    Tigerland (2000)       0          0          0
# 3951             Two Family House (2000)       0          0          0
# 3952               Contender, The (2000)       0          0          0
#
#       Children's  Comedy  Crime  Documentary  Drama  Fantasy  Film-Noir  \
# Id
# 1              1       1      0            0      0        0          0
# 2              1       0      0            0      0        1          0
# 3              0       1      0            0      0        0          0
# 4              0       1      0            0      1        0          0
# 5              0       1      0            0      0        0          0
# ...          ...     ...    ...          ...    ...      ...        ...
# 3948           0       1      0            0      0        0          0
# 3949           0       0      0            0      1        0          0
# 3950           0       0      0            0      1        0          0
# 3951           0       0      0            0      1        0          0
# 3952           0       0      0            0      1        0          0
#
#       Horror  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western
# Id
# 1          0        0        0        0       0         0    0        0
# 2          0        0        0        0       0         0    0        0
# 3          0        0        0        1       0         0    0        0
# 4          0        0        0        0       0         0    0        0
# 5          0        0        0        0       0         0    0        0
# ...      ...      ...      ...      ...     ...       ...  ...      ...
# 3948       0        0        0        0       0         0    0        0
# 3949       0        0        0        0       0         0    0        0
# 3950       0        0        0        0       0         0    0        0
# 3951       0        0        0        0       0         0    0        0
# 3952       0        0        0        0       0         1    0        0
#
# [3883 rows x 19 columns]

# %%
load_dotenv()
TMDB_API_TOKEN = os.getenv("TMDB_API_TOKEN")

# %%
load_dotenv()

headers = {"Authorization": f"Bearer {TMDB_API_TOKEN}", "Accept": "application/json"}

# %%
def get_tmdb_metadata(row):
    match = re.match(r"(.*?)\s*\((\d{4})\)\s*$", row['Name'])
    if not match:
        return pd.Series()
    
    title = match.group(1).strip()
    year = match.group(2)
    
    params = {
        "query": title,
        "primary_release_year": year,
        "page": 1
    }
    
    try:
        response = requests.get(
            "https://api.themoviedb.org/3/search/movie",
            headers=headers,
            params=params
        )
        time.sleep(0.05)
        
        if response.status_code == 200:
            results = response.json().get('results', [])
            if results:
                return pd.Series({
                    'adult': results[0].get('adult'),
                    'original_language': results[0].get('original_language'),
                    'overview': results[0].get('overview'),
                    'popularity': results[0].get('popularity'),
                    'vote_average': results[0].get('vote_average'),
                    'vote_count': results[0].get('vote_count')
                })
        return pd.Series()
        
    except Exception as e:
        print(f"Error fetching data for {title}: {str(e)}")
        return pd.Series()

# %%
tmdb_metadata = df_movies.apply(get_tmdb_metadata, axis=1)
df_movies = pd.concat([df_movies, tmdb_metadata], axis=1)

# %%
df_movies
# Out:
#                                     Name  Action  Adventure  Animation  \
# Id
# 1                       Toy Story (1995)       0          0          1
# 2                         Jumanji (1995)       0          1          0
# 3                Grumpier Old Men (1995)       0          0          0
# 4               Waiting to Exhale (1995)       0          0          0
# 5     Father of the Bride Part II (1995)       0          0          0
# ...                                  ...     ...        ...        ...
# 3948             Meet the Parents (2000)       0          0          0
# 3949          Requiem for a Dream (2000)       0          0          0
# 3950                    Tigerland (2000)       0          0          0
# 3951             Two Family House (2000)       0          0          0
# 3952               Contender, The (2000)       0          0          0
#
#       Children's  Comedy  Crime  Documentary  Drama  Fantasy  ...  Sci-Fi  \
# Id                                                            ...
# 1              1       1      0            0      0        0  ...       0
# 2              1       0      0            0      0        1  ...       0
# 3              0       1      0            0      0        0  ...       0
# 4              0       1      0            0      1        0  ...       0
# 5              0       1      0            0      0        0  ...       0
# ...          ...     ...    ...          ...    ...      ...  ...     ...
# 3948           0       1      0            0      0        0  ...       0
# 3949           0       0      0            0      1        0  ...       0
# 3950           0       0      0            0      1        0  ...       0
# 3951           0       0      0            0      1        0  ...       0
# 3952           0       0      0            0      1        0  ...       0
#
#       Thriller  War  Western  adult  original_language  \
# Id
# 1            0    0        0  False                 en
# 2            0    0        0  False                 en
# 3            0    0        0  False                 en
# 4            0    0        0  False                 en
# 5            0    0        0  False                 en
# ...        ...  ...      ...    ...                ...
# 3948         0    0        0  False                 en
# 3949         0    0        0  False                 en
# 3950         0    0        0  False                 en
# 3951         0    0        0  False                 en
# 3952         1    0        0  False                 en
#
#                                                overview  popularity  \
# Id
# 1     Led by Woody, Andy's toys live happily in his ...     22.5087
# 2     When siblings Judy and Peter discover an encha...      2.8748
# 3     A family wedding reignites the ancient feud be...      3.3388
# 4     Cheated on, mistreated and stepped on, the wom...      1.4856
# 5     Just when George Banks has recovered from his ...      1.8580
# ...                                                 ...         ...
# 3948  Greg Focker is ready to marry his girlfriend, ...      6.7783
# 3949  The drug-induced utopias of four Coney Island ...      4.3849
# 3950  A group of recruits go through Advanced Infant...      1.5951
# 3951  Buddy Visalo (Michael Rispoli) is a factory wo...      0.2276
# 3952  The vice president is dead, and as the preside...      2.1470
#
#       vote_average vote_count
# Id
# 1            7.970    19055.0
# 2            7.240    10866.0
# 3            6.467      403.0
# 4            6.267      174.0
# 5            6.251      762.0
# ...            ...        ...
# 3948         6.685     6111.0
# 3949         8.015    10436.0
# 3950         6.609      580.0
# 3951         6.400       18.0
# 3952         6.700      251.0
#
# [3883 rows x 25 columns]

# %%
df_users.to_csv("../../datasets/train_users.csv")
df_ratings.to_csv("../../datasets/train_ratings.csv")
df_movies.to_csv("../../datasets/train_movies.csv")

# %%
df_ratings_reset = df_ratings.reset_index()
movies_ratings = pd.merge(
    df_ratings_reset, df_movies, left_on="MovieID", right_on="Id", how="left"
)

# %%
merged_df = pd.merge(
    movies_ratings, df_users, left_on="UserID", right_on="Id", how="inner"
)

# %%
merged_df.to_csv("../../datasets/full_test_dataset.csv")
